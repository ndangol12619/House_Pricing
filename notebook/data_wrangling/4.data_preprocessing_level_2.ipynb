# %%
import os
import sys
# Add src/ to sys.path (relative to current notebook)
sys.path.append(os.path.abspath("../../src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib

from utils.DataAnalysis import TableAnalysis, MyCustomException
from utils.VariableAnalysis import UnivariateAnalysis,BivariateAnalysis
from utils.pdf_file_save import PDFReportWriter

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
file_path = pathlib.Path('D:\Capstone Project\dataset\House_Price_dataset')
df = pd.read_csv(f"{file_path}/3.gurgaon_properties.csv")
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 48 Gurgaon         house
# 1                            2 BHK Flat in Sohna          flat
# 2               2 BHK Flat in Sector 88A Gurgaon          flat
# 3                2 BHK Flat in Sector 90 Gurgaon          flat
# 4                3 BHK Flat in Sector 68 Gurgaon          flat
#
#                  society  price  price_per_sqft    area  \
# 0     vipul tatvam villa   7.35         22812.0  3222.0
# 1  signature global park   0.54          6388.0   845.0
# 2           godrej oasis   1.00          6896.0  1450.0
# 3            green court   0.47          6811.0   690.0
# 4         m3m the marina   2.22         14322.0  1550.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 358(299.33 sq.m.)        4         5
# 1  Super Built up area 845.3(78.53 sq.m.)Carpet a...        2         2
# 2                   Carpet area: 1450 (134.71 sq.m.)        2         2
# 3                      Carpet area: 690 (64.1 sq.m.)        2         2
# 4                Super Built up area 1550(144 sq.m.)        3         2
#
#   balcony                                 additionalRoom  \
# 0       2  servant room,store room,study room,pooja room
# 1       3                                  not available
# 2       3                                     study room
# 3       1                                  not available
# 4       3                                  not available
#
#                                     address  floorNum facing  \
# 0  001, Sector 48 Gurgaon, Gurgaon, Haryana       2.0  South
# 1  M3 Fourth Floor, Sohna, Gurgaon, Haryana       4.0   East
# 2      Sector 88A Gurgaon, Gurgaon, Haryana       7.0    NaN
# 3       Sector 90 Gurgaon, Gurgaon, Haryana       0.0   East
# 4       Sector 68 Gurgaon, Gurgaon, Haryana       4.0   East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 1   0 to 1 Year Old  ['Sector 55-56 metro', 'Global city centre', '...
# 2   1 to 5 Year Old  ['Double Infinity market', 'Pataudi road', 'Dw...
# 3   0 to 1 Year Old  ['Baba Kanala Chowk', 'Pataudi Rd', 'Gurukul P...
# 4   1 to 5 Year Old  ['Airia Mall', 'Southern Peripheral Road', 'So...
#
#                                          description  \
# 0  Tatvam villas is one of the most luxurious res...
# 1  Check out this 2 bhk flat for sale in signatur...
# 2  This beautiful 2 bhk flat in sector-88a gurgao...
# 3  Park facing, only 04 flats on floor, both side...
# 4      Aravali pahadi view\nVer spacious \nLow floor
#
#                                       furnishDetails  \
# 0  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '14 L...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Fan', '1 Exhaust Fan', '7 Light', 'No AC',...
# 4  ['6 Fan', '10 Light', '4 AC', 'No Bed', 'No Ch...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Green Area3 out of 5', 'Amenities4 out of 5'...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
df.sample(5)
# Out:
#                                           property_name property_type  \
# 1033  5 Bedroom House for sale in Jacobpura Near Sad...         house
# 2455                    4 BHK Flat in Sector 9A Gurgaon          flat
# 1295                   1 BHK Flat in Sector 103 Gurgaon          flat
# 3251   12 Bedroom House for sale in Sushant Lok Phase 3         house
# 35                      4 BHK Flat in Sector 70 Gurgaon          flat
#
#                            society  price  price_per_sqft    area  \
# 1033            jacobpura gurugram   1.30         23557.0   552.0
# 2455  railway officers rpf society   1.25          6921.0  1806.0
# 1295    signature global grand iva   0.30          8290.0   362.0
# 3251                   independent   6.95         38611.0  1800.0
# 35                     tulip ivory   2.00          8333.0  2400.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1033                        Plot area 56.6(47.32 sq.m.)        5         2
# 2455                   Carpet area: 1806 (167.78 sq.m.)        4         3
# 1295                  Carpet area: 361.88 (33.62 sq.m.)        1         2
# 3251                        Plot area 192(160.54 sq.m.)       12        12
# 35    Super Built up area 2400(222.97 sq.m.)Carpet a...        4         5
#
#      balcony           additionalRoom  \
# 1033       1                   others
# 2455       3             servant room
# 1295       2            not available
# 3251      3+  servant room,store room
# 35        3+             servant room
#
#                                                 address  floorNum      facing  \
# 1033  520/8 Jacobpura Gurugram Gali Number 2, Jacobp...       3.0  South-West
# 2455  101, Tower A, Sector 9A Gurgaon, Gurgaon, Haryana       1.0  South-West
# 1295               Sector 103 Gurgaon, Gurgaon, Haryana       5.0         NaN
# 3251              Sushant Lok Phase 3, Gurgaon, Haryana       4.0        East
# 35                  Sector 70 Gurgaon, Gurgaon, Haryana       7.0  North-East
#
#          agePossession                                    nearbyLocations  \
# 1033      10+ Year Old  ['Hanuman Mandir', 'Sharma Hospital Gurgaon', ...
# 2455      10+ Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Esic...
# 1295   0 to 1 Year Old  ['Dwaraka Expy, Tikampur Village', 'Sector 108...
# 3251   0 to 1 Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 35    5 to 10 Year Old  ['Reach 3 Roads Shopping Mall', 'Southern Peri...
#
#                                             description  \
# 1033  Close to metro station, close to school, close...
# 2455  4bhk flat/apartment for sale in rpf housing so...
# 1295  Residential apartment for sell.Located on 5th ...
# 3251  Entire building for sale (Floor wise ) in sect...
# 35    Tulip ivory 4bhk in sector 70, gurgaon is a re...
#
#                                          furnishDetails  \
# 1033  ['2 Wardrobe', '6 Fan', '20 Light', 'No AC', '...
# 2455  ['3 Wardrobe', '1 Exhaust Fan', '3 Geyser', '1...
# 1295                                                 []
# 3251  ['1 Water Purifier', '1 Exhaust Fan', '1 Stove...
# 35    ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
#
#                                                features  \
# 1033                                                NaN
# 2455  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 1295  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 3251  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 35    ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating
# 1033                                                NaN
# 2455  ['Connectivity4 out of 5', 'Lifestyle4 out of ...
# 1295  ['Green Area5 out of 5', 'Construction5 out of...
# 3251  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 35    ['Green Area3.5 out of 5', 'Construction3.5 ou...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 48 Gurgaon         house
# 1                            2 BHK Flat in Sohna          flat
# 2               2 BHK Flat in Sector 88A Gurgaon          flat
# 3                2 BHK Flat in Sector 90 Gurgaon          flat
# 4                3 BHK Flat in Sector 68 Gurgaon          flat
#
#                  society  price  price_per_sqft    area  \
# 0     vipul tatvam villa   7.35         22812.0  3222.0
# 1  signature global park   0.54          6388.0   845.0
# 2           godrej oasis   1.00          6896.0  1450.0
# 3            green court   0.47          6811.0   690.0
# 4         m3m the marina   2.22         14322.0  1550.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 358(299.33 sq.m.)        4         5
# 1  Super Built up area 845.3(78.53 sq.m.)Carpet a...        2         2
# 2                   Carpet area: 1450 (134.71 sq.m.)        2         2
# 3                      Carpet area: 690 (64.1 sq.m.)        2         2
# 4                Super Built up area 1550(144 sq.m.)        3         2
#
#   balcony                                 additionalRoom  \
# 0       2  servant room,store room,study room,pooja room
# 1       3                                  not available
# 2       3                                     study room
# 3       1                                  not available
# 4       3                                  not available
#
#                                     address  floorNum facing  \
# 0  001, Sector 48 Gurgaon, Gurgaon, Haryana       2.0  South
# 1  M3 Fourth Floor, Sohna, Gurgaon, Haryana       4.0   East
# 2      Sector 88A Gurgaon, Gurgaon, Haryana       7.0    NaN
# 3       Sector 90 Gurgaon, Gurgaon, Haryana       0.0   East
# 4       Sector 68 Gurgaon, Gurgaon, Haryana       4.0   East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 1   0 to 1 Year Old  ['Sector 55-56 metro', 'Global city centre', '...
# 2   1 to 5 Year Old  ['Double Infinity market', 'Pataudi road', 'Dw...
# 3   0 to 1 Year Old  ['Baba Kanala Chowk', 'Pataudi Rd', 'Gurukul P...
# 4   1 to 5 Year Old  ['Airia Mall', 'Southern Peripheral Road', 'So...
#
#                                          description  \
# 0  Tatvam villas is one of the most luxurious res...
# 1  Check out this 2 bhk flat for sale in signatur...
# 2  This beautiful 2 bhk flat in sector-88a gurgao...
# 3  Park facing, only 04 flats on floor, both side...
# 4      Aravali pahadi view\nVer spacious \nLow floor
#
#                                       furnishDetails  \
# 0  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '14 L...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Fan', '1 Exhaust Fan', '7 Light', 'No AC',...
# 4  ['6 Fan', '10 Light', '4 AC', 'No Bed', 'No Ch...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Green Area3 out of 5', 'Amenities4 out of 5'...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
## Add Sector Column 
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

## Lowering Sector Value
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 48 Gurgaon         house
# 1                            2 BHK Flat in Sohna          flat
# 2               2 BHK Flat in Sector 88A Gurgaon          flat
# 3                2 BHK Flat in Sector 90 Gurgaon          flat
# 4                3 BHK Flat in Sector 68 Gurgaon          flat
#
#                  society      sector  price  price_per_sqft    area  \
# 0     vipul tatvam villa   sector 48   7.35         22812.0  3222.0
# 1  signature global park       sohna   0.54          6388.0   845.0
# 2           godrej oasis  sector 88a   1.00          6896.0  1450.0
# 3            green court   sector 90   0.47          6811.0   690.0
# 4         m3m the marina   sector 68   2.22         14322.0  1550.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 358(299.33 sq.m.)        4         5
# 1  Super Built up area 845.3(78.53 sq.m.)Carpet a...        2         2
# 2                   Carpet area: 1450 (134.71 sq.m.)        2         2
# 3                      Carpet area: 690 (64.1 sq.m.)        2         2
# 4                Super Built up area 1550(144 sq.m.)        3         2
#
#   balcony                                 additionalRoom  \
# 0       2  servant room,store room,study room,pooja room
# 1       3                                  not available
# 2       3                                     study room
# 3       1                                  not available
# 4       3                                  not available
#
#                                     address  floorNum facing  \
# 0  001, Sector 48 Gurgaon, Gurgaon, Haryana       2.0  South
# 1  M3 Fourth Floor, Sohna, Gurgaon, Haryana       4.0   East
# 2      Sector 88A Gurgaon, Gurgaon, Haryana       7.0    NaN
# 3       Sector 90 Gurgaon, Gurgaon, Haryana       0.0   East
# 4       Sector 68 Gurgaon, Gurgaon, Haryana       4.0   East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 1   0 to 1 Year Old  ['Sector 55-56 metro', 'Global city centre', '...
# 2   1 to 5 Year Old  ['Double Infinity market', 'Pataudi road', 'Dw...
# 3   0 to 1 Year Old  ['Baba Kanala Chowk', 'Pataudi Rd', 'Gurukul P...
# 4   1 to 5 Year Old  ['Airia Mall', 'Southern Peripheral Road', 'So...
#
#                                          description  \
# 0  Tatvam villas is one of the most luxurious res...
# 1  Check out this 2 bhk flat for sale in signatur...
# 2  This beautiful 2 bhk flat in sector-88a gurgao...
# 3  Park facing, only 04 flats on floor, both side...
# 4      Aravali pahadi view\nVer spacious \nLow floor
#
#                                       furnishDetails  \
# 0  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '14 L...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Fan', '1 Exhaust Fan', '7 Light', 'No AC',...
# 4  ['6 Fan', '10 Light', '4 AC', 'No Bed', 'No Ch...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Green Area3 out of 5', 'Amenities4 out of 5'...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                                      163
# sector 102                                 113
# sector 85                                  110
# sector 92                                  104
# sector 69                                   94
#                                           ...
# saraswati enclave                            1
# khandsa                                      1
# saroop garden rajendra park                  1
# block h ashok vihar phase iii extension      1
# sector 42                                    1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road           163
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# sector 15              3
# sector 73              3
# b block sector 43      3
# sector 17a             3
# patel nagar            3
# Name: count, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 1096  2 BHK Flat in New Gurgaon          flat                   green court
# 1870  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2158  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 3593  4 BHK Flat in New Gurgaon          flat                    sare homes
#
#      sector  price  price_per_sqft    area  \
# 1096    new   0.38          5507.0   690.0
# 1870    new   4.00         11428.0  3500.0
# 2158    new   0.67          5583.0  1200.0
# 3593    new   0.85          4786.0  1776.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 1096           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 1870        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 2158  Super Built up area 1200(111.48 sq.m.)        2         2       2
# 3593     Super Built up area 1776(165 sq.m.)        4         4       3
#
#                additionalRoom                        address  floorNum facing  \
# 1096            not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
# 1870  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 2158            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 3593            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 1096  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 1870            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2158     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3593    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 1096  We are the proud owners of this 2 bhk apartmen...
# 1870  This lovely 4 bhk apartment/flat in new gurgao...
# 2158  Check out this 2 bhk apartment for sale in tak...
# 3593  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 1096                                                 []
# 1870  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2158                                                 []
# 3593                                                 []
#
#                                                features rating
# 1096  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 1870  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2158  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 3593                                                NaN    NaN

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 123   2 Bedroom House for sale in New Palam Vihar         house
# 1524                2 BHK Flat in New Palam Vihar          flat
# 2469  3 Bedroom House for sale in New Palam Vihar         house
# 2571                2 BHK Flat in New Palam Vihar          flat
# 2886                2 BHK Flat in New Palam Vihar          flat
#
#                   society        sector  price  price_per_sqft    area  \
# 123               my home  new sector 2   0.34         12592.0   270.0
# 1524              my home  new sector 2   0.28          3166.0   884.0
# 2469          independent  new sector 2   1.00          8796.0  1137.0
# 2571              my home  new sector 2   0.22          4400.0   500.0
# 2886  ompee k s residency  new sector 2   1.60         26936.0   594.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 123                          Plot area 270(25.08 sq.m.)        2         2
# 1524                     Carpet area: 900 (83.61 sq.m.)        2         1
# 2469  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 2571                     Carpet area: 500 (46.45 sq.m.)        2         2
# 2886                      Carpet area: 66 (55.18 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 123        2  not available
# 1524       1         others
# 2469       2     pooja room
# 2571       1  not available
# 2886       2  not available
#
#                                                 address  floorNum facing  \
# 123          Ez-19 A, New Palam Vihar, Gurgaon, Haryana       3.0   West
# 1524         F 150/b, New Palam Vihar, Gurgaon, Haryana       2.0    NaN
# 2469  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...       1.0  North
# 2571                  New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 2886                  New Palam Vihar, Gurgaon, Haryana       1.0    NaN
#
#          agePossession                                    nearbyLocations  \
# 123   5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1524   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2469      10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2571   0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2886   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 123   There are availability of various facilities l...
# 1524  2 bhk room with wooden coverd ,1 drawing room,...
# 2469  Ground and first floor, Ground floor: Ground f...
# 2571  Cctv surveillance are provided here. There is ...
# 2886  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 123   ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 1524  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2469                                                NaN
# 2571  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2886                                                NaN
#
#                                           features  \
# 123   ['Water Storage', 'Park', 'Visitor Parking']
# 1524                     ['Water Storage', 'Park']
# 2469                                           NaN
# 2571                                           NaN
# 2886                                           NaN
#
#                                                  rating
# 123   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1524  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2469  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2571  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2886  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 48 Gurgaon         house
# 1                            2 BHK Flat in Sohna          flat
# 2               2 BHK Flat in Sector 88A Gurgaon          flat
# 3                2 BHK Flat in Sector 90 Gurgaon          flat
# 4                3 BHK Flat in Sector 68 Gurgaon          flat
#
#                  society      sector  price  price_per_sqft    area  \
# 0     vipul tatvam villa   sector 48   7.35         22812.0  3222.0
# 1  signature global park  sohna road   0.54          6388.0   845.0
# 2           godrej oasis  sector 88a   1.00          6896.0  1450.0
# 3            green court   sector 90   0.47          6811.0   690.0
# 4         m3m the marina   sector 68   2.22         14322.0  1550.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 358(299.33 sq.m.)        4         5
# 1  Super Built up area 845.3(78.53 sq.m.)Carpet a...        2         2
# 2                   Carpet area: 1450 (134.71 sq.m.)        2         2
# 3                      Carpet area: 690 (64.1 sq.m.)        2         2
# 4                Super Built up area 1550(144 sq.m.)        3         2
#
#   balcony                                 additionalRoom  \
# 0       2  servant room,store room,study room,pooja room
# 1       3                                  not available
# 2       3                                     study room
# 3       1                                  not available
# 4       3                                  not available
#
#                                     address  floorNum facing  \
# 0  001, Sector 48 Gurgaon, Gurgaon, Haryana       2.0  South
# 1  M3 Fourth Floor, Sohna, Gurgaon, Haryana       4.0   East
# 2      Sector 88A Gurgaon, Gurgaon, Haryana       7.0    NaN
# 3       Sector 90 Gurgaon, Gurgaon, Haryana       0.0   East
# 4       Sector 68 Gurgaon, Gurgaon, Haryana       4.0   East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 1   0 to 1 Year Old  ['Sector 55-56 metro', 'Global city centre', '...
# 2   1 to 5 Year Old  ['Double Infinity market', 'Pataudi road', 'Dw...
# 3   0 to 1 Year Old  ['Baba Kanala Chowk', 'Pataudi Rd', 'Gurukul P...
# 4   1 to 5 Year Old  ['Airia Mall', 'Southern Peripheral Road', 'So...
#
#                                          description  \
# 0  Tatvam villas is one of the most luxurious res...
# 1  Check out this 2 bhk flat for sale in signatur...
# 2  This beautiful 2 bhk flat in sector-88a gurgao...
# 3  Park facing, only 04 flats on floor, both side...
# 4      Aravali pahadi view\nVer spacious \nLow floor
#
#                                       furnishDetails  \
# 0  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '14 L...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Fan', '1 Exhaust Fan', '7 Light', 'No AC',...
# 4  ['6 Fan', '10 Light', '4 AC', 'No Bed', 'No Ch...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Green Area3 out of 5', 'Amenities4 out of 5'...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                  society      sector  price  \
# 1016          flat  sidhartha ncr one phase   sector 95   0.56
# 1578         house              independent   sector 43   5.25
# 1383          flat     umang monsoon breeze   sector 78   1.25
# 2597          flat        kashish manor one  sector 111   1.65
# 2005          flat      smart world orchard   sector 61   1.65
#
#       price_per_sqft    area  \
# 1016          4105.0  1364.0
# 1578         27132.0  1935.0
# 1383          5000.0  2500.0
# 2597          7097.0  2325.0
# 2005         13750.0  1200.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1016             Super Built up area 1364(126.72 sq.m.)        2         2
# 1578                        Plot area 215(179.77 sq.m.)        4         4
# 1383  Super Built up area 2350(218.32 sq.m.)Built Up...        4         4
# 2597                Super Built up area 2325(216 sq.m.)        3         4
# 2005                   Carpet area: 1200 (111.48 sq.m.)        2         2
#
#      balcony                  additionalRoom  floorNum facing  \
# 1016       2                   not available      10.0    NaN
# 1578       2         study room,servant room       2.0    NaN
# 1383       3  servant room,others,pooja room       2.0   East
# 2597      3+             servant room,others      14.0    NaN
# 2005       2                      study room       1.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 1016     1 to 5 Year Old  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 1578        10+ Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 1383     1 to 5 Year Old  ['Proposed Metro Station', 'Mahapal Shing', 'N...
# 2597  Under Construction  ['HUDA Sector 23 Market', 'Palam Vihar Vyapar ...
# 2005             By 2023  ['Sector 55-56 Metro station', 'Bestech Centra...
#
#                                          furnishDetails  \
# 1016  ['4 Fan', '1 Exhaust Fan', '2 Geyser', '8 Ligh...
# 1578  ['4 Wardrobe', '4 Fan', '4 Geyser', '12 Light'...
# 1383  ['1 Water Purifier', 'No AC', 'No Bed', 'No Ch...
# 2597                                                 []
# 2005                                                 []
#
#                                                features
# 1016  ['Lift(s)', 'Maintenance Staff', 'Swimming Poo...
# 1578  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1383  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 2597  ['Park', 'Club house / Community Center', 'Wat...
# 2005  ['Power Back-up', 'Lift(s)', 'Swimming Pool', ...

# %%
# feature engineering required -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features

# %%
df.duplicated().sum()
# Out:
# np.int64(121)

# %%
df.to_csv(f'{file_path}/4.gurgaon_properties_cleaned_v1.csv',index=False)
