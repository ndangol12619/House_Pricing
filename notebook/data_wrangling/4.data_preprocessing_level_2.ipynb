# %%
import os
import sys
# Add src/ to sys.path (relative to current notebook)
sys.path.append(os.path.abspath("../../src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib

from utils.DataAnalysis import TableAnalysis, MyCustomException
from utils.VariableAnalysis import UnivariateAnalysis,BivariateAnalysis
from utils.pdf_file_save import PDFReportWriter

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
file_path = pathlib.Path('D:\Capstone Project\dataset\House_Price_dataset')
df = pd.read_csv(f"{file_path}/3.gurgaon_properties.csv")
df.head()
# Out:
#                                     property_name property_type  \
# 0                2 BHK Flat in Sector 107 Gurgaon          flat
# 1                      2 BHK Flat in Laxman Vihar          flat
# 2  8 Bedroom House for sale in Sector 105 Gurgaon         house
# 3                3 BHK Flat in Sector 111 Gurgaon          flat
# 4         3 Bedroom House for sale in Ashok Vihar         house
#
#              society  price  price_per_sqft    area  \
# 0      m3m woodshire   0.80          5856.0  1366.0
# 1     not applicable   0.42          5600.0   750.0
# 2        independent   0.60         11102.0   540.0
# 3  kashish manor one   1.65          7097.0  2325.0
# 4        independent   0.90         10000.0   900.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1366(126.91 sq.m.)        2         2
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                          Plot area 60(50.17 sq.m.)        8         4
# 3                Super Built up area 2325(216 sq.m.)        3         4
# 4  Plot area 900(83.61 sq.m.)Built Up area: 3500 ...        3         4
#
#   balcony       additionalRoom  \
# 0      3+        not available
# 1       1        not available
# 2       3        not available
# 3      3+  servant room,others
# 4       3               others
#
#                                              address  floorNum      facing  \
# 0               Sector 107 Gurgaon, Gurgaon, Haryana       7.0  North-East
# 1  621/622, Gali No-4, Laxman Vihar, Gurgaon, Har...       3.0         NaN
# 2       C 93 B, Sector 105 Gurgaon, Gurgaon, Haryana       3.0        West
# 3               Sector 111 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 4       Phase 3 Extn., Ashok Vihar, Gurgaon, Haryana       3.0         NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 1     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2     0 to 1 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Bhar...
# 3  Under Construction  ['HUDA Sector 23 Market', 'Palam Vihar Vyapar ...
# 4    5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  M3m woodshire is one of the most popular desti...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Property with modern upgradesPlease write a pr...
# 3  Kashish manor one is located just 0 km from de...
# 4  L shape plot. Commercial cum residential const...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Li...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['9 Fan', '17 Light', 'No AC', 'No Bed', 'No C...
# 3                                                 []
# 4  ['1 Bed', '5 Wardrobe', '1 Water Purifier', '4...
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2               ['Private Garden / Terrace', 'Park']
# 3  ['Park', 'Club house / Community Center', 'Wat...
# 4  ['Feng Shui / Vaastu Compliant', 'Water Storag...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction5 out ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.sample(5)
# Out:
#                                           property_name property_type  \
# 3592                    3 BHK Flat in Sector 92 Gurgaon          flat
# 2664                    3 BHK Flat in Sector 83 Gurgaon          flat
# 3257                   1 BHK Flat in Sector 107 Gurgaon          flat
# 87    5 Bedroom House for sale in Block G Sector-57 ...         house
# 3448                    4 BHK Flat in Sector 83 Gurgaon          flat
#
#                       society  price  price_per_sqft    area  \
# 3592       sare crescent parc   0.82          5384.0  1523.0
# 2664           vatika gurgaon   1.05          7000.0  1500.0
# 3257  signature global solera   0.25          7862.0   318.0
# 87                independent   1.35         24545.0   550.0
# 3448           vatika gurgaon   1.40          7179.0  1950.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3592                 Built Up area: 1523 (141.49 sq.m.)        3         3
# 2664  Super Built up area 1735(161.19 sq.m.)Carpet a...        3         3
# 3257                   Built Up area: 318 (29.54 sq.m.)        1         1
# 87                            Plot area 550(51.1 sq.m.)        5         3
# 3448                   Carpet area: 1950 (181.16 sq.m.)        4         4
#
#      balcony additionalRoom  \
# 3592      3+  not available
# 2664       3     store room
# 3257       0  not available
# 87         2  not available
# 3448       3   servant room
#
#                                                 address  floorNum      facing  \
# 3592     Sector 92, Sector 92 Gurgaon, Gurgaon, Haryana      12.0        West
# 2664                Sector 83 Gurgaon, Gurgaon, Haryana       3.0  South-West
# 3257   Sector 107, Sector 107 Gurgaon, Gurgaon, Haryana       0.0         NaN
# 87    G1139, Block G Sector-57 Gurgaon, Gurgaon, Har...       3.0  South-East
# 3448                Sector 83 Gurgaon, Gurgaon, Haryana      10.0  North-East
#
#         agePossession                                    nearbyLocations  \
# 3592        undefined                                                NaN
# 2664  1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
# 3257        undefined  ['Gurgaon Dreamz Mall', 'Dwarka Expressway', "...
# 87       10+ Year Old  ['Sector metro station', 'Sector metro station...
# 3448  1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
#
#                                             description  \
# 3592  3bhk multistorey apartment for resale in sare ...
# 2664  Located in the popular residential address of ...
# 3257  1bhk multistorey apartment for resale in signa...
# 87    Posh location, nice locality. Independent hous...
# 3448  Vatika gurgaon 21 is one of the most popular d...
#
#                                          furnishDetails  \
# 3592  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2664                                                NaN
# 3257                                                NaN
# 87    ['1 Water Purifier', '1 Fan', '1 Light', '1 Wa...
# 3448                                                NaN
#
#                                                features  \
# 3592                                                NaN
# 2664  ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'M...
# 3257                                                NaN
# 87     ['Maintenance Staff', 'Park', 'Visitor Parking']
# 3448  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                                  rating
# 3592  ['Green Area4 out of 5', 'Amenities3 out of 5'...
# 2664  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3257  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 87                                                  NaN
# 3448  ['Green Area5 out of 5', 'Construction4.5 out ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                2 BHK Flat in Sector 107 Gurgaon          flat
# 1                      2 BHK Flat in Laxman Vihar          flat
# 2  8 Bedroom House for sale in Sector 105 Gurgaon         house
# 3                3 BHK Flat in Sector 111 Gurgaon          flat
# 4         3 Bedroom House for sale in Ashok Vihar         house
#
#              society  price  price_per_sqft    area  \
# 0      m3m woodshire   0.80          5856.0  1366.0
# 1     not applicable   0.42          5600.0   750.0
# 2        independent   0.60         11102.0   540.0
# 3  kashish manor one   1.65          7097.0  2325.0
# 4        independent   0.90         10000.0   900.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1366(126.91 sq.m.)        2         2
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                          Plot area 60(50.17 sq.m.)        8         4
# 3                Super Built up area 2325(216 sq.m.)        3         4
# 4  Plot area 900(83.61 sq.m.)Built Up area: 3500 ...        3         4
#
#   balcony       additionalRoom  \
# 0      3+        not available
# 1       1        not available
# 2       3        not available
# 3      3+  servant room,others
# 4       3               others
#
#                                              address  floorNum      facing  \
# 0               Sector 107 Gurgaon, Gurgaon, Haryana       7.0  North-East
# 1  621/622, Gali No-4, Laxman Vihar, Gurgaon, Har...       3.0         NaN
# 2       C 93 B, Sector 105 Gurgaon, Gurgaon, Haryana       3.0        West
# 3               Sector 111 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 4       Phase 3 Extn., Ashok Vihar, Gurgaon, Haryana       3.0         NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 1     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2     0 to 1 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Bhar...
# 3  Under Construction  ['HUDA Sector 23 Market', 'Palam Vihar Vyapar ...
# 4    5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  M3m woodshire is one of the most popular desti...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Property with modern upgradesPlease write a pr...
# 3  Kashish manor one is located just 0 km from de...
# 4  L shape plot. Commercial cum residential const...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Li...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['9 Fan', '17 Light', 'No AC', 'No Bed', 'No C...
# 3                                                 []
# 4  ['1 Bed', '5 Wardrobe', '1 Water Purifier', '4...
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2               ['Private Garden / Terrace', 'Park']
# 3  ['Park', 'Club house / Community Center', 'Wat...
# 4  ['Feng Shui / Vaastu Compliant', 'Water Storag...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction5 out ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
## Add Sector Column 
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

## Lowering Sector Value
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                2 BHK Flat in Sector 107 Gurgaon          flat
# 1                      2 BHK Flat in Laxman Vihar          flat
# 2  8 Bedroom House for sale in Sector 105 Gurgaon         house
# 3                3 BHK Flat in Sector 111 Gurgaon          flat
# 4         3 Bedroom House for sale in Ashok Vihar         house
#
#              society        sector  price  price_per_sqft    area  \
# 0      m3m woodshire    sector 107   0.80          5856.0  1366.0
# 1     not applicable  laxman vihar   0.42          5600.0   750.0
# 2        independent    sector 105   0.60         11102.0   540.0
# 3  kashish manor one    sector 111   1.65          7097.0  2325.0
# 4        independent   ashok vihar   0.90         10000.0   900.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1366(126.91 sq.m.)        2         2
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                          Plot area 60(50.17 sq.m.)        8         4
# 3                Super Built up area 2325(216 sq.m.)        3         4
# 4  Plot area 900(83.61 sq.m.)Built Up area: 3500 ...        3         4
#
#   balcony       additionalRoom  \
# 0      3+        not available
# 1       1        not available
# 2       3        not available
# 3      3+  servant room,others
# 4       3               others
#
#                                              address  floorNum      facing  \
# 0               Sector 107 Gurgaon, Gurgaon, Haryana       7.0  North-East
# 1  621/622, Gali No-4, Laxman Vihar, Gurgaon, Har...       3.0         NaN
# 2       C 93 B, Sector 105 Gurgaon, Gurgaon, Haryana       3.0        West
# 3               Sector 111 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 4       Phase 3 Extn., Ashok Vihar, Gurgaon, Haryana       3.0         NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 1     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2     0 to 1 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Bhar...
# 3  Under Construction  ['HUDA Sector 23 Market', 'Palam Vihar Vyapar ...
# 4    5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  M3m woodshire is one of the most popular desti...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Property with modern upgradesPlease write a pr...
# 3  Kashish manor one is located just 0 km from de...
# 4  L shape plot. Commercial cum residential const...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Li...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['9 Fan', '17 Light', 'No AC', 'No Bed', 'No C...
# 3                                                 []
# 4  ['1 Bed', '5 Wardrobe', '1 Water Purifier', '4...
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2               ['Private Garden / Terrace', 'Park']
# 3  ['Park', 'Club house / Community Center', 'Wat...
# 4  ['Feng Shui / Vaastu Compliant', 'Water Storag...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction5 out ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                   163
# sector 102              113
# sector 85               110
# sector 92               104
# sector 69                94
#                        ...
# near nand hospital        1
# huda saraswati vihar      1
# heritage city             1
# part 3 sector 5           1
# tekchand nagar            1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road           163
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# sector 73              3
# sector 110 a           3
# sector 17a             3
# sector 17b             3
# b block sector 43      3
# Name: count, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 890   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 1535  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2791  4 BHK Flat in New Gurgaon          flat                    sare homes
# 3949  2 BHK Flat in New Gurgaon          flat                   green court
#
#      sector  price  price_per_sqft    area  \
# 890     new   0.67          5583.0  1200.0
# 1535    new   4.00         11428.0  3500.0
# 2791    new   0.85          4786.0  1776.0
# 3949    new   0.38          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 890   Super Built up area 1200(111.48 sq.m.)        2         2       2
# 1535        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 2791     Super Built up area 1776(165 sq.m.)        4         4       3
# 3949           Carpet area: 690 (64.1 sq.m.)        2         2       1
#
#                additionalRoom                        address  floorNum facing  \
# 890             not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 1535  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 2791            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 3949            not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 890      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 1535            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2791    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 3949  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
#
#                                             description  \
# 890   Check out this 2 bhk apartment for sale in tak...
# 1535  This lovely 4 bhk apartment/flat in new gurgao...
# 2791  Located in the popular residential address of ...
# 3949  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 890                                                  []
# 1535  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2791                                                 []
# 3949                                                 []
#
#                                                features rating
# 890   ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 1535  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2791                                                NaN    NaN
# 3949  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 704                 2 BHK Flat in New Palam Vihar          flat
# 714                 2 BHK Flat in New Palam Vihar          flat
# 1079                2 BHK Flat in New Palam Vihar          flat
# 1711  3 Bedroom House for sale in New Palam Vihar         house
# 2589  2 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 704               my home  new sector 2   0.22          4400.0   500.0
# 714   ompee k s residency  new sector 2   1.60         26936.0   594.0
# 1079              my home  new sector 2   0.28          3166.0   884.0
# 1711          independent  new sector 2   1.00          8796.0  1137.0
# 2589              my home  new sector 2   0.34         12592.0   270.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 704                      Carpet area: 500 (46.45 sq.m.)        2         2
# 714                       Carpet area: 66 (55.18 sq.m.)        2         2
# 1079                     Carpet area: 900 (83.61 sq.m.)        2         1
# 1711  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 2589                         Plot area 270(25.08 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 704        1  not available
# 714        2  not available
# 1079       1         others
# 1711       2     pooja room
# 2589       2  not available
#
#                                                 address  floorNum facing  \
# 704                   New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 714                   New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 1079         F 150/b, New Palam Vihar, Gurgaon, Haryana       2.0    NaN
# 1711  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...       1.0  North
# 2589         Ez-19 A, New Palam Vihar, Gurgaon, Haryana       3.0   West
#
#          agePossession                                    nearbyLocations  \
# 704    0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 714    1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1079   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1711      10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2589  5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 704   Cctv surveillance are provided here. There is ...
# 714   We are the proud owners of this 2 bhk apartmen...
# 1079  2 bhk room with wooden coverd ,1 drawing room,...
# 1711  Ground and first floor, Ground floor: Ground f...
# 2589  There are availability of various facilities l...
#
#                                          furnishDetails  \
# 704   ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 714                                                 NaN
# 1079  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 1711                                                NaN
# 2589  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
#
#                                           features  \
# 704                                            NaN
# 714                                            NaN
# 1079                     ['Water Storage', 'Park']
# 1711                                           NaN
# 2589  ['Water Storage', 'Park', 'Visitor Parking']
#
#                                                  rating
# 704   ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 714   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1079  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1711  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2589  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                2 BHK Flat in Sector 107 Gurgaon          flat
# 1                      2 BHK Flat in Laxman Vihar          flat
# 2  8 Bedroom House for sale in Sector 105 Gurgaon         house
# 3                3 BHK Flat in Sector 111 Gurgaon          flat
# 4         3 Bedroom House for sale in Ashok Vihar         house
#
#              society      sector  price  price_per_sqft    area  \
# 0      m3m woodshire  sector 107   0.80          5856.0  1366.0
# 1     not applicable    sector 4   0.42          5600.0   750.0
# 2        independent  sector 105   0.60         11102.0   540.0
# 3  kashish manor one  sector 111   1.65          7097.0  2325.0
# 4        independent    sector 3   0.90         10000.0   900.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1366(126.91 sq.m.)        2         2
# 1                     Carpet area: 750 (69.68 sq.m.)        2         2
# 2                          Plot area 60(50.17 sq.m.)        8         4
# 3                Super Built up area 2325(216 sq.m.)        3         4
# 4  Plot area 900(83.61 sq.m.)Built Up area: 3500 ...        3         4
#
#   balcony       additionalRoom  \
# 0      3+        not available
# 1       1        not available
# 2       3        not available
# 3      3+  servant room,others
# 4       3               others
#
#                                              address  floorNum      facing  \
# 0               Sector 107 Gurgaon, Gurgaon, Haryana       7.0  North-East
# 1  621/622, Gali No-4, Laxman Vihar, Gurgaon, Har...       3.0         NaN
# 2       C 93 B, Sector 105 Gurgaon, Gurgaon, Haryana       3.0        West
# 3               Sector 111 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 4       Phase 3 Extn., Ashok Vihar, Gurgaon, Haryana       3.0         NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 1     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 2     0 to 1 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Bhar...
# 3  Under Construction  ['HUDA Sector 23 Market', 'Palam Vihar Vyapar ...
# 4    5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  M3m woodshire is one of the most popular desti...
# 1  Flat build on, two side open plot with 18 feet...
# 2  Property with modern upgradesPlease write a pr...
# 3  Kashish manor one is located just 0 km from de...
# 4  L shape plot. Commercial cum residential const...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Li...
# 1  ['4 Wardrobe', '1 Water Purifier', '2 Fan', '1...
# 2  ['9 Fan', '17 Light', 'No AC', 'No Bed', 'No C...
# 3                                                 []
# 4  ['1 Bed', '5 Wardrobe', '1 Water Purifier', '4...
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Lift(s)', 'Water purifier', 'Maintenance Sta...
# 2               ['Private Garden / Terrace', 'Park']
# 3  ['Park', 'Club house / Community Center', 'Wat...
# 4  ['Feng Shui / Vaastu Compliant', 'Water Storag...
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction5 out ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                   society      sector  price  \
# 3038          flat  maxworth city residences  sector 10a   0.90
# 2739         house               independent  sector 105   1.35
# 3104          flat              tulip violet   sector 69   1.70
# 2426          flat               m3m heights   sector 65   2.29
# 113          house           bhim garh kheri    sector 3   0.75
#
#       price_per_sqft    area  \
# 3038          7083.0  1271.0
# 2739          3857.0  3500.0
# 3104          8457.0  2010.0
# 2426         15980.0  1433.0
# 113           6410.0  1170.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3038             Super Built up area 1200(111.48 sq.m.)        2         2
# 2739  Built Up area: 3500 (325.16 sq.m.)Carpet area:...        5         3
# 3104  Super Built up area 2010(186.74 sq.m.)Carpet a...        4         4
# 2426                   Carpet area: 1433 (133.13 sq.m.)        2         2
# 113                          Plot area 130(108.7 sq.m.)        4         2
#
#      balcony                                 additionalRoom  floorNum  \
# 3038       3                                         others       9.0
# 2739       3                                  not available       3.0
# 3104       2  pooja room,study room,servant room,store room      10.0
# 2426       3                                     study room       8.0
# 113        2                                  not available       2.0
#
#           facing       agePossession  \
# 3038        East     0 to 1 Year Old
# 2739        East           undefined
# 3104  South-West     1 to 5 Year Old
# 2426         NaN  Under Construction
# 113         West        10+ Year Old
#
#                                         nearbyLocations  \
# 3038  ['Rajiv Chowk Mosque', 'Yadav Hospital Gurgoan...
# 2739  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3104  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 2426  ['Rapid Metro Sector 56', 'M3m 65th Avenue Mal...
# 113   ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          furnishDetails  \
# 3038                                                 []
# 2739  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 3104  ['4 Wardrobe', '4 Fan', '1 Exhaust Fan', '9 Li...
# 2426                                                NaN
# 113   ['1 Light', '1 Chimney', 'No AC', 'No Bed', 'N...
#
#                                                features
# 3038  ['Security / Fire Alarm', 'Intercom Facility',...
# 2739                                                NaN
# 3104  ['Centrally Air Conditioned', 'Water purifier'...
# 2426           ['Intercom Facility', 'Lift(s)', 'Park']
# 113       ['Private Garden / Terrace', 'Water Storage']

# %%
# feature engineering required -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features

# %%
df.shape
# Out:
# (3803, 17)

# %%
df.duplicated().sum()
# Out:
# np.int64(122)

# %%
df.to_csv(f'{file_path}/4.gurgaon_properties_cleaned_v1.csv',index=False)
